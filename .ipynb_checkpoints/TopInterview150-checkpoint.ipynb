# %% [markdown]
# Array / String

# %%
# 88. Merge Sorted Array
class Solution(object):
    def merge(self, nums1, m, nums2, n):
        """
        :type nums1: List[int]
        :type m: int
        :type nums2: List[int]
        :type n: int
        :rtype: None Do not return anything, modify nums1 in-place instead.
        """
        # Initialize pointers for nums1, nums2, and the merged array
        p1, p2, p = m - 1, n - 1, m + n - 1
        
        # Merge nums1 and nums2 into nums1
        while p1 >= 0 and p2 >= 0:
            if nums1[p1] > nums2[p2]:
                nums1[p] = nums1[p1]
                p1 -= 1
            else:
                nums1[p] = nums2[p2]
                p2 -= 1
            p -= 1

        # If there are remaining elements in nums2, copy them to nums1
        while p2 >= 0:
            nums1[p] = nums2[p2]
            p2 -= 1
            p -= 1

# Create an instance of the Solution class
solution = Solution()

# Input: nums1 = [1,2,3,0,0,0], m = 3, nums2 = [2,5,6], n = 3
# Output: [1,2,2,3,5,6]
nums1 = [1, 2, 3, 0, 0, 0]
m = 3
nums2 = [2, 5, 6]
n = 3

# Input: nums1 = [1], m = 1, nums2 = [], n = 0
# Output: [1]
# nums1 = [1]
# m = 1
# nums2 = []
# n = 0

# Input: nums1 = [0], m = 0, nums2 = [1], n = 1
# Output: [1]
# nums1 = [0]
# m = 0
# nums2 = [1]
# n = 1

solution.merge(nums1, m, nums2, n)
print(nums1)  # Output: [1, 2, 2, 3, 5, 6]
# Out:
# [1, 2, 2, 3, 5, 6]

# %%
# 27. Remove Element
class Solution:
    def removeElement(self, nums, val):
        """
        :type nums: List[int]
        :type val: int
        :rtype: int
        """
        k = 0  # Initialize k to keep track of the number of elements not equal to val

        for i in range(len(nums)):
            if nums[i] != val:
                nums[k] = nums[i]
                k += 1

        return k
            
# Create an instance of the Solution class
solution = Solution()

# Input: nums = [3,2,2,3], val = 3
# Output: 2, nums = [2,2,_,_]
nums = [3, 2, 2, 3]
val = 3

# Input: nums = [0,1,2,2,3,0,4,2], val = 2
# Output: 5, nums = [0,1,4,0,3,_,_,_]
# nums = [0, 1, 2, 2, 3, 0, 4, 2]
# val = 2

# Call the removeElement method to remove 'val' from the list 'nums'
k = solution.removeElement(nums, val)

# Print the updated list containing elements not equal to 'val'
print("New Array:", nums[:k])  # Elements not equal to 'val'

# Print the number of elements not equal to 'val'
print("Number of elements not equal to 'val':", k)
# Out:
# New Array: [2, 2]
# Number of elements not equal to 'val': 2

# %%
# 26. Remove Duplicates from Sorted Array
class Solution(object):
    def removeDuplicates(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        k = 0
        
        for i in range(1, len(nums)):
            if nums[i] != nums[k]:
                k += 1
                nums[k] = nums[i] # Only when nums[i] != nums[k], nums[k] will update the list
                    
        k = k + 1
        return k

# Create an instance of the Solution class
solution = Solution()

# Input: nums = [1,1,2]
# Output: 2, nums = [1,2,_]
# nums = [1, 1, 2]

# Input: nums = [0,0,1,1,1,2,2,3,3,4]
# Output: 5, nums = [0,1,2,3,4,_,_,_,_,_]
nums = [0, 0, 1, 1, 1, 2, 2, 3, 3, 4]

# Print the updated list containing elements not equal to 'val'
k = solution.removeDuplicates(nums)
print("New Array:", nums[:k])

# Print the number of elements not equal to 'val'
print("Number of elements not equal to 'val':", k)
# Out:
# New Array: [0, 1, 2, 3, 4]
# Number of elements not equal to 'val': 5

# %%
# 80. Remove Duplicates from Sorted Array II
class Solution(object):
    def removeDuplicates(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        k = 0
        
        for i in range(len(nums)):
            # If the index does not match elements, count that element and update it...
            if k < 2 or nums[i] != nums[k - 2]:
                nums[k] = nums[i]
                k += 1
        return k

# Create an instance of the Solution class
solution = Solution()

# Input: nums = [1,1,1,2,2,3]
# Output: 5, nums = [1,1,2,2,3,_]
# nums = [1,1,1,2,2,3]

# Input: nums = [0,0,1,1,1,1,2,3,3]
# Output: 7, nums = [0,0,1,1,2,3,3,_,_]
nums = [0, 0, 1, 1, 1, 1, 2, 3, 3]

k = solution.removeDuplicates(nums)
print("New Array:", nums[:k])
print("New Array:", nums)

# Print the number of elements not equal to 'val'
print("Number of elements not equal to 'val':", k)
# Out:
# New Array: [0, 0, 1, 1, 2, 3, 3]
# New Array: [0, 0, 1, 1, 2, 3, 3, 3, 3]
# Number of elements not equal to 'val': 7

# %%
# 169. Majority Element
class Solution(object):
    def majorityElement(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        
        # Initialize variables for the majority element and its count
        majority = nums[0]
        count = 1

        # Loop through the array starting from the second element
        for i in range(1, len(nums)):
            if count == 0:
                majority = nums[i]
                count = 1
            elif nums[i] == majority:
                count += 1
            else:
                count -= 1

        return majority
    
# Create an instance of the Solution class
solution = Solution()

# # Input: nums = [3,2,3]
# Output: 3
# nums = [3,2,3]

# Input: nums = [2,2,1,1,1,2,2]
# Output: 2
nums = [2,2,1,1,1,2,2]

k = solution.majorityElement(nums)
# print("New Array:", nums[:k])
# print("New Array:", nums)

# Print the number of elements not equal to 'val'
print("Number of elements not equal to 'val':", k)
# Out:
# Number of elements not equal to 'val': 2

# %%
# 189. Rotate Array
class Solution(object):
    def rotate(self, nums, k):
        """
        :type nums: List[int]
        :type k: int
        :rtype: None Do not return anything, modify nums in-place instead.
        """
        
#         while k > 0:
#             nums[:] = nums[-1:]+ nums[:-1]
#             k = k - 1
            
        # Calculate the effective rotation amount, which is k modulo the length of the array
        # Value of k is larger than the length of the array
        k = k % len(nums)
        
        # Use slicing to rotate the array to the right
        # Would be creating a new list and assigning it to the variable nums
        nums[:] = nums[-k:] + nums[:-k]

# Create an instance of the Solution class
solution = Solution()

# Input: nums = [1,2,3,4,5,6,7], k = 3
# Output: [5,6,7,1,2,3,4]
nums = [1,2,3,4,5,6,7]
k = 3
solution.rotate(nums, k)
print(nums)

# Input: nums = [-1,-100,3,99], k = 2
# Output: [3,99,-1,-100]
nums = [-1,-100,3,99]
k = 2
solution.rotate(nums, k)
print(nums)
# Out:
# [5, 6, 7, 1, 2, 3, 4]
# [3, 99, -1, -100]

# %%
# 121. Best Time to Buy and Sell Stock
# Solution 1
class Solution(object):
    def maxProfit(self, prices):
        """
        :type prices: List[int]
        :rtype: int
        """
        maximum_profit = 0
        
        for i in range(len(prices)):
            for j in range(i, len(prices)):
                profit = prices[j] - prices[i]
                if profit > maximum_profit:
                    maximum_profit = profit

        return maximum_profit

# Create an instance of the Solution class
solution = Solution()

# Input: prices = [7,1,5,3,6,4]
# Output: 5
prices = [7,1,5,3,6,4]
    
# Input: prices = [7,6,4,3,1]
# Output: 0
# prices = [7,6,4,3,1]

k = solution.maxProfit(prices)
print(k)
# Out:
# 5

# %%
# 121. Best Time to Buy and Sell Stock
# Solution 2
class Solution(object):
    def maxProfit(self, prices):
        """
        :type prices: List[int]
        :rtype: int
        """
        minimum_price = prices[0]
        maximum_profit = 0

        for price in prices:
            if price < minimum_price:
                minimum_price = price
            elif price - minimum_price > maximum_profit:
                maximum_profit = price - minimum_price
        return maximum_profit

# Create an instance of the Solution class
solution = Solution()

# Input: prices = [7,1,5,3,6,4]
# Output: 5
prices = [7,1,5,3,6,4]
    
# Input: prices = [7,6,4,3,1]
# Output: 0
# prices = [7,6,4,3,1]

k = solution.maxProfit(prices)
print(k)
# Out:
# 5

# %%
# 122. Best Time to Buy and Sell Stock II
class Solution(object):
    def maxProfit(self, prices):
        """
        :type prices: List[int]
        :rtype: int
        """
        max_profit = 0

        for i in range(1, len(prices)):
            if prices[i] > prices[i - 1]:
                max_profit += prices[i] - prices[i - 1]

        return max_profit

# Create an instance of the Solution class
solution = Solution()

# Input: prices = [7,1,5,3,6,4]
# Output: 5
prices = [7,1,5,3,6,4]
    
# Input: prices = [7,6,4,3,1]
# Output: 0
# prices = [7,6,4,3,1]

k = solution.maxProfit(prices)
print(k)
# Out:
# 7

# %%
# 55. Jump Game
class Solution(object):
    def canJump(self, nums):
        """
        :type nums: List[int]
        :rtype: bool
        """
        max_reach = 0  # Initialize the maximum index you can reach to 0
        for i in range(len(nums)):
            if i > max_reach:
                return False  # If you cannot reach index 'i', return false
            max_reach = max(max_reach, i + nums[i])  # Update the maximum index you can reach
            print(max_reach)
            if max_reach >= len(nums) - 1:
                return True  # If you can reach the end of the array, return true
        return False  # If you finish iterating and can't reach the end, return false

# Create an instance of the Solution class
solution = Solution()

# Input: nums = [2,3,1,1,4]
# Output: true
nums = [2,3,1,1,4]
print(solution.canJump(nums))

# Input: nums = [3,2,1,0,4]
# Output: false
# nums = [3,2,1,0,4]
# print(solution.canJump(nums))
# Out:
# 2
# 4
# True

# %%
# 45. Jump Game II
class Solution(object):
    def jump(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        n = len(nums)
        if n == 1:
            return 0

        dp = [float('inf')] * n
        dp[0] = 0

        for i in range(1, n):
            for j in range(i):
                if j + nums[j] >= i:
                    dp[i] = min(dp[i], dp[j] + 1)

        return dp[n - 1]
    
# Create an instance of the Solution class
solution = Solution()

# Input: nums = [2,3,1,1,4]
# Output: 2
nums = [2,3,1,1,4]
output = solution.jump(nums)
print(output)

# Input: nums = [2,3,0,1,4]
# Output: 2
nums = [2,3,0,1,4]
output = solution.jump(nums)
print(output)
# Out:
# 2
# 2

# %%
# 274. H-Index

class Solution(object):
    def hIndex(self, citations):
        """
        :type citations: List[int]
        :rtype: int
        """
        k = len(citations) # Guess the hIndex from big to small
        j = len(citations) # Get how many citations is >= k in this round
        
        while k >= 0:
            for i in range(len(citations)):
                if citations[i] < k:
                    j = j - 1
            if k <= j:
                return k
            else:
                k = k - 1
                j = len(citations)

# Create an instance of the Solution class
solution = Solution()

# Input: citations = [3,0,6,1,5]
# Output: 3
citations = [3,0,6,1,5]
output = solution.hIndex(citations)
print(output)

# Input: citations = [1,3,1]
# Output: 1
# Out:
# 3

# %%
# 380. Insert Delete GetRandom O(1)
class RandomizedSet(object):

    def __init__(self):
    # Initialize the data structures.
        self.val_to_index = {}  # A dictionary to store values as keys and their corresponding indices in the array as values.
        self.vals = []  # An array to store the values.
        

    def insert(self, val):
        """
        :type val: int
        :rtype: bool
        """
        if val in self.val_to_index:
            return False

        # Add the value to the array and update the dictionary.
        self.val_to_index[val] = len(self.vals)
        self.vals.append(val)
        return True
        

    def remove(self, val):
        """
        :type val: int
        :rtype: bool
        """
        if val not in self.val_to_index:
            return False

        # Swap the value to remove with the last value in the array.
        last_val = self.vals[-1]
        index_to_remove = self.val_to_index[val]
        self.vals[index_to_remove] = last_val
        self.val_to_index[last_val] = index_to_remove

        # Pop the last value and remove the value from the dictionary.
        self.vals.pop()
        del self.val_to_index[val]
        return True
        

    def getRandom(self):
        """
        :rtype: int
        """
        return random.choice(self.vals)

# Your RandomizedSet object will be instantiated and called as such:
obj = RandomizedSet()
param_1 = obj.insert(1)
param_1 = obj.insert(2)
param_1 = obj.insert(5)
param_1 = obj.insert(7)
param_1 = obj.insert(8)
print(obj.vals)
param_2 = obj.remove(2)
print(obj.vals)
# param_3 = obj.getRandom()
# Out:
# [1, 2, 5, 7, 8]
# [1, 8, 5, 7]

# %%
# 3. Roman to Integer
class Solution(object):
    def romanToInt(self, s):
        """
        :type s: str
        :rtype: int
        I             1
        V             5
        X             10
        L             50
        C             100
        D             500
        M             1000
        """
        
        roman = {
            "I": 1,
            "V": 5,
            "X": 10,
            "L": 50,
            "C": 100,
            "D": 500,
            "M": 1000
        }
        total = 0
        
        s = s.replace("IV", "IIII").replace("IX", "VIIII")
        s = s.replace("XL", "XXXX").replace("XC", "LXXXX")
        s = s.replace("CD", "CCCC").replace("CM", "DCCCC")
        
        for symbol in s:
            total += roman[symbol]
        return total

# Create an instance of the Solution class
solution = Solution()

# Input: s = "III"
# Output: 3
# s = "III"

# Input: s = "LVIII"
# Output: 58
s = "LVIII"

k = solution.romanToInt(s)
print(k)
# Out:
# 58

# %%
# 58. Length of Last Word
class Solution(object):
    def lengthOfLastWord(self, s):
        """
        :type s: str
        :rtype: int
        """
        words = s.split()
        k = len(words[-1])
        return k

# Create an instance of the Solution class
solution = Solution()

# Input: s = "Hello World"
# Output: 5
s = "Hello World"

# Input: s = "   fly me   to   the moon  "
# Output: 4
s = "   fly me   to   the moon  "

k = solution.lengthOfLastWord(s)
print(k)
# Out:
# 4

# %%
# 14. Longest Common Prefix
class Solution(object):
    def longestCommonPrefix(self, strs):
        """
        :type strs: List[str]
        :rtype: str
        """
        # Find the shortest string in the array
        min_str = min(strs, key=len)

        for i, char in enumerate(min_str):
            for string in strs:
                if string[i] != char:
                    return min_str[:i]

        return min_str
    
# Create an instance of the Solution class
solution = Solution()

# Input: strs = ["flower","flow","flight"]
# Output: "fl"
# strs = ["flower","flow","flight"]
# output = solution.longestCommonPrefix(strs)
# print(output)
    
# Input: strs = ["dog","racecar","car"]
# Output: ""
strs = ["dog","racecar","car"]
output = solution.longestCommonPrefix(strs)
print(output)

# %%
# 28. Find the Index of the First Occurrence in a String
class Solution(object):
    def strStr(self, haystack, needle):
        """
        :type haystack: str
        :type needle: str
        :rtype: int
        """
        index = haystack.find(needle)
        return index

# Create an instance of the Solution class
solution = Solution()

# Input: haystack = "sadbutsad", needle = "sad"
# Output: 0
haystack = "sadbutsad"
needle = "sad"
output = solution.strStr(haystack, needle)
print(output)
    
# Input: haystack = "leetcode", needle = "leeto"
# Output: -1
haystack = "leetcode"
needle = "leeto"
output = solution.strStr(haystack, needle)
print(output)
# Out:
# 0
# -1
